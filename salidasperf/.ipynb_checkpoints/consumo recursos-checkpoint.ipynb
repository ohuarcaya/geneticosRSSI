# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# PLoting
lista_modelos = []
for i in range(12):
    lista_modelos.append(pd.read_csv('salidamodelo'+str(i)+'.csv', sep=';', index_col=False))

# %%
lista_modelos[0].describe()
# Out:
#        tiempo(Segundos)  energia(Joules)        ciclos  instrucciones  \
# count         48.000000        48.000000  4.800000e+01   4.800000e+01
# mean           0.003925         0.183542  9.062517e+07   2.765214e+07
# std            0.004301         0.245656  1.456794e+08   2.255372e+07
# min            0.001412         0.010000  8.692876e+06   2.228610e+05
# 25%            0.001491         0.040000  9.309123e+06   1.324444e+07
# 50%            0.001560         0.065000  1.483502e+07   1.625448e+07
# 75%            0.003397         0.190000  6.040275e+07   2.998665e+07
# max            0.015771         0.810000  4.803411e+08   8.380532e+07
#
#        inst/ciclo  porcentajecpu
# count   48.000000      38.000000
# mean     1.331458      64.589474
# std      0.496327      23.413948
# min      0.430000      12.220000
# 25%      0.865000      46.632500
# 50%      1.445000      60.620000
# 75%      1.752500      83.725000
# max      2.010000     100.000000

# %%
#indice = 0,1,2
def boxplot_csv(lista_modelos, indice_columna):
    # %pylab inline
    pylab.rcParams['figure.figsize'] = (14, 8)
    names = ['LoR', 'LDA', 'GNB', 'MLP', 'SVC', 'DT', 'k-NN', 'RF', 'ET', 'GBM', 'AB', 'VC']
    y_ejeName = ['Energy (J.)', 'Inst/cicle', 'CPU (%)']
    box_graphic_name = []
    column_list = list(lista_modelos[0].columns[[1,4,5,0]])
    df = pd.DataFrame(columns=names)
    column_plot = column_list[indice_columna]# 'energia(Joules)'
    column_time = column_list[-1]#'tiempo(Segundos)'
    interval_time = 0.001 # milesima de segundo
    #create dataframe
    ld = [len(lista_modelos2[i][column_plot]) for i in list(range(12))]
    index_top = ld.index(max(ld))
    df[names[index_top]] = lista_modelos[index_top][column_plot]
    for i in range(12):
        #df[names[i]] = lista_modelos[i]['energia(Joules)']*1000
        # estandarize
        df[names[i]] = lista_modelos[i][column_plot]*interval_time/lista_modelos[i][column_time]
    #display(df.head())
    """
        PLOT
    """
    medians = np.round(list(df.mean()),3)
    median_labels = [str(i) for i in medians]
    sns.set_style("whitegrid")
    y_label = y_ejeName[indice_columna]
    x_label = 'Models'
    ax_plot = sns.boxplot(data=df, linewidth = 1.0)
    ax_plot.set_xlabel(x_label,fontsize=18)
    ax_plot.set_ylabel(y_label,fontsize=18)
    plt.rc('xtick', labelsize=15) 
    plt.rc('ytick', labelsize=15)

    tope = [0.1, 3, 100][indice_columna]
    var_tope = [0.01, 0.2, 5][indice_columna]
    pos = range(len(names))
    for tick,label in zip(pos,ax_plot.get_xticklabels()):
        ax_plot.text(pos[tick], tope-var_tope, median_labels[tick], 
                horizontalalignment='center', color='black', fontsize=15) #, weight='semibold'
    axes = plt.gca()
    axes.set_ylim([-var_tope/2, tope])
    print(column_list[indice_columna])
    plt.savefig('go' + '.eps', bbox_inches='tight')

# %% [markdown]
# # MULTIHILO

# %%
boxplot_csv(lista_modelos, 0)
# Out:
# energia(Joules)

# %%
boxplot_csv(lista_modelos, 1)
# Out:
# inst/ciclo

# %%
boxplot_csv(lista_modelos, 2)
# Out:
# porcentajecpu

# %% [markdown]
# # SECUENCIAL

# %%
lista_modelos2 = []
for i in range(12):
    lista_modelos2.append(pd.read_csv('salidamodelo'+str(i)+'v2.csv', sep=';', index_col=False))

# %%
lista_modelos2[0].describe()
# Out:
#        tiempo(Segundos)  energia(Joules)        ciclos  instrucciones  \
# count         45.000000        45.000000  4.500000e+01   4.500000e+01
# mean           0.003975         0.194222  1.031334e+08   3.693596e+07
# std            0.004178         0.245852  1.511939e+08   5.102999e+07
# min            0.001404         0.010000  8.287017e+06   1.906867e+06
# 25%            0.001496         0.040000  1.121589e+07   1.549188e+07
# 50%            0.001531         0.060000  1.489301e+07   2.680689e+07
# 75%            0.007836         0.370000  2.374511e+08   2.949760e+07
# max            0.011912         0.680000  4.843813e+08   3.350842e+08
#
#        inst/ciclo  porcentajecpu
# count   45.000000      38.000000
# mean     1.271556      60.306579
# std      0.539604      28.795361
# min      0.210000       0.000000
# 25%      0.810000      41.077500
# 50%      1.010000      53.475000
# 75%      1.830000      89.205000
# max      2.010000     100.000000

# %%
boxplot_csv(lista_modelos2, 0)
# Out:
# energia(Joules)

# %%
boxplot_csv(lista_modelos2, 1)
# Out:
# inst/ciclo

# %%
boxplot_csv(lista_modelos2, 2)
# Out:
# porcentajecpu
